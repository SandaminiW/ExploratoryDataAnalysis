# %%
import pandas as pd
import seaborn as sns

# %%
df =pd.read_csv('/content/TWO_CENTURIES_OF_UM_RACES.csv')

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (18660, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                   float64
# dtype: object

# %% [markdown]
# Clean up data

# %%
df[df['Event distance/length'] == '50km']
# Out:
#        Year of event Event dates             Event name Event distance/length  \
# 0               2018  06.01.2018    Selva Costera (CHI)                  50km
# 1               2018  06.01.2018    Selva Costera (CHI)                  50km
# 2               2018  06.01.2018    Selva Costera (CHI)                  50km
# 3               2018  06.01.2018    Selva Costera (CHI)                  50km
# 4               2018  06.01.2018    Selva Costera (CHI)                  50km
# ...              ...         ...                    ...                   ...
# 17410           2018  17.03.2018  Om Die Dam 50km (RSA)                  50km
# 17411           2018  17.03.2018  Om Die Dam 50km (RSA)                  50km
# 17412           2018  17.03.2018  Om Die Dam 50km (RSA)                  50km
# 17413           2018  17.03.2018  Om Die Dam 50km (RSA)                  50km
# 17414           2018  17.03.2018  Om Die Dam 50km (RSA)                  50km
#
# ...

# %%
#combine 50km/50mi with isin
df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#        Year of event Event dates                               Event name  \
# 0               2018  06.01.2018                      Selva Costera (CHI)
# 1               2018  06.01.2018                      Selva Costera (CHI)
# 2               2018  06.01.2018                      Selva Costera (CHI)
# 3               2018  06.01.2018                      Selva Costera (CHI)
# 4               2018  06.01.2018                      Selva Costera (CHI)
# ...              ...         ...                                      ...
# 17592           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
# 17593           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
# 17594           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
# 17595           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
# 17596           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2018)]
# Out:
#        Year of event Event dates                               Event name  \
# 0               2018  06.01.2018                      Selva Costera (CHI)
# 1               2018  06.01.2018                      Selva Costera (CHI)
# 2               2018  06.01.2018                      Selva Costera (CHI)
# 3               2018  06.01.2018                      Selva Costera (CHI)
# 4               2018  06.01.2018                      Selva Costera (CHI)
# ...              ...         ...                                      ...
# 17592           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
# 17593           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
# 17594           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
# 17595           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
# 17596           2018  17.03.2018  Big Buffalo 50 Mile Endurance Run (USA)
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[df['Event name'] == 'Selva Costera (CHI)']['Event name'].str.split(')')
# Out:
# 0     [Selva Costera (CHI, ]
# 1     [Selva Costera (CHI, ]
# 2     [Selva Costera (CHI, ]
# 3     [Selva Costera (CHI, ]
# 4     [Selva Costera (CHI, ]
# 5     [Selva Costera (CHI, ]
# 6     [Selva Costera (CHI, ]
# 7     [Selva Costera (CHI, ]
# 8     [Selva Costera (CHI, ]
# 9     [Selva Costera (CHI, ]
# 10    [Selva Costera (CHI, ]
# 11    [Selva Costera (CHI, ]
# 12    [Selva Costera (CHI, ]
# 13    [Selva Costera (CHI, ]
# 14    [Selva Costera (CHI, ]
# 15    [Selva Costera (CHI, ]
# 16    [Selva Costera (CHI, ]
# 17    [Selva Costera (CHI, ]
# 18    [Selva Costera (CHI, ]
# 19    [Selva Costera (CHI, ]
# 20    [Selva Costera (CHI, ]
# 21    [Selva Costera (CHI, ]
# Name: Event name, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'CHI']
# Out:
#     Year of event Event dates           Event name Event distance/length  \
# 0            2018  06.01.2018  Selva Costera (CHI)                  50km
# 1            2018  06.01.2018  Selva Costera (CHI)                  50km
# 2            2018  06.01.2018  Selva Costera (CHI)                  50km
# 3            2018  06.01.2018  Selva Costera (CHI)                  50km
# 4            2018  06.01.2018  Selva Costera (CHI)                  50km
# 5            2018  06.01.2018  Selva Costera (CHI)                  50km
# 6            2018  06.01.2018  Selva Costera (CHI)                  50km
# 7            2018  06.01.2018  Selva Costera (CHI)                  50km
# 8            2018  06.01.2018  Selva Costera (CHI)                  50km
# 9            2018  06.01.2018  Selva Costera (CHI)                  50km
# 10           2018  06.01.2018  Selva Costera (CHI)                  50km
# 11           2018  06.01.2018  Selva Costera (CHI)                  50km
# ...

# %% [markdown]
# combine all the filters together

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2018) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'CHI') ]
# Out:
#     Year of event Event dates           Event name Event distance/length  \
# 0            2018  06.01.2018  Selva Costera (CHI)                  50km
# 1            2018  06.01.2018  Selva Costera (CHI)                  50km
# 2            2018  06.01.2018  Selva Costera (CHI)                  50km
# 3            2018  06.01.2018  Selva Costera (CHI)                  50km
# 4            2018  06.01.2018  Selva Costera (CHI)                  50km
# 5            2018  06.01.2018  Selva Costera (CHI)                  50km
# 6            2018  06.01.2018  Selva Costera (CHI)                  50km
# 7            2018  06.01.2018  Selva Costera (CHI)                  50km
# 8            2018  06.01.2018  Selva Costera (CHI)                  50km
# 9            2018  06.01.2018  Selva Costera (CHI)                  50km
# 10           2018  06.01.2018  Selva Costera (CHI)                  50km
# 11           2018  06.01.2018  Selva Costera (CHI)                  50km
# ...

# %%
df2= df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2018) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'CHI') ]

# %% [markdown]
# Remove (CHI) from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 0     Selva Costera
# 1     Selva Costera
# 2     Selva Costera
# 3     Selva Costera
# 4     Selva Costera
# 5     Selva Costera
# 6     Selva Costera
# 7     Selva Costera
# 8     Selva Costera
# 9     Selva Costera
# 10    Selva Costera
# 11    Selva Costera
# 12    Selva Costera
# 13    Selva Costera
# 14    Selva Costera
# 15    Selva Costera
# 16    Selva Costera
# 17    Selva Costera
# 18    Selva Costera
# 19    Selva Costera
# 20    Selva Costera
# 21    Selva Costera
# Name: Event name, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# <ipython-input-21-3d011d1d997c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head()
# Out:
#    Year of event Event dates      Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera                   50km
# 1           2018  06.01.2018  Selva Costera                   50km
# 2           2018  06.01.2018  Selva Costera                   50km
# 3           2018  06.01.2018  Selva Costera                   50km
# 4           2018  06.01.2018  Selva Costera                   50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %% [markdown]
# clean up athlete age

# %%
df2['athlete age'] = 2018 - df2['Athlete year of birth']
# Out:
# <ipython-input-23-f9f57a9725aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete age'] = 2018 - df2['Athlete year of birth']

# %% [markdown]
# remove h from athlete performance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# <ipython-input-24-fe95f03be5db>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head()
# Out:
#    Year of event Event dates      Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera                   50km
# 1           2018  06.01.2018  Selva Costera                   50km
# 2           2018  06.01.2018  Selva Costera                   50km
# 3           2018  06.01.2018  Selva Costera                   50km
# 4           2018  06.01.2018  Selva Costera                   50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22             4:51:39               Tnfrc
# 1                         22             5:15:45  Roberto Echeverría
# 2                         22             5:16:44   Puro Trail Osorno
# 3                         22             5:34:13            Columbia
# 4                         22             5:54:14      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %% [markdown]
# Drop columns: Athlete club', 'Athlete country', 'Athlete year of birth	Athlete', 'Athlete age category'

# %%
df2 = df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis=1)

# %%
df2.head()
# Out:
#    Year of event Event dates      Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera                   50km
# 1           2018  06.01.2018  Selva Costera                   50km
# 2           2018  06.01.2018  Selva Costera                   50km
# 3           2018  06.01.2018  Selva Costera                   50km
# 4           2018  06.01.2018  Selva Costera                   50km
#
#    Event number of finishers Athlete performance Athlete gender  \
# 0                         22             4:51:39              M
# 1                         22             5:15:45              M
# 2                         22             5:16:44              M
# 3                         22             5:34:13              M
# 4                         22             5:54:14              M
#
#   Athlete average speed  Athlete ID  athlete age
# 0                10.286         0.0         40.0
# 1                 9.501         1.0         37.0
# ...

# %% [markdown]
# Clean up null values

# %%
df2.isnull().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# athlete age                  3
# dtype: int64

# %%
df2[df2['athlete age'].isna()==1]
# Out:
#     Year of event Event dates      Event name Event distance/length  \
# 11           2018  06.01.2018  Selva Costera                   50km
# 19           2018  06.01.2018  Selva Costera                   50km
# 20           2018  06.01.2018  Selva Costera                   50km
#
#     Event number of finishers Athlete performance Athlete gender  \
# 11                         22             7:09:58              M
# 19                         22             8:13:16              M
# 20                         22             8:13:28              M
#
#    Athlete average speed  Athlete ID  athlete age
# 11                 6.977        11.0          NaN
# 19                 6.082        19.0          NaN
# 20                 6.079        20.0          NaN

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (19, 10)

# %% [markdown]
# check for dupes

# %%
df2[df2.duplicated()] == True
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete age]
# Index: []

# %% [markdown]
# Reset index

# %%
df2.reset_index(drop=True)
# Out:
#     Year of event Event dates      Event name Event distance/length  \
# 0            2018  06.01.2018  Selva Costera                   50km
# 1            2018  06.01.2018  Selva Costera                   50km
# 2            2018  06.01.2018  Selva Costera                   50km
# 3            2018  06.01.2018  Selva Costera                   50km
# 4            2018  06.01.2018  Selva Costera                   50km
# 5            2018  06.01.2018  Selva Costera                   50km
# 6            2018  06.01.2018  Selva Costera                   50km
# 7            2018  06.01.2018  Selva Costera                   50km
# 8            2018  06.01.2018  Selva Costera                   50km
# 9            2018  06.01.2018  Selva Costera                   50km
# 10           2018  06.01.2018  Selva Costera                   50km
# 11           2018  06.01.2018  Selva Costera                   50km
# 12           2018  06.01.2018  Selva Costera                   50km
# ...

# %% [markdown]
# Fix Types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                   float64
# athlete age                  float64
# dtype: object

# %%
df2['athlete age'] = df2['athlete age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                   float64
# athlete age                    int64
# dtype: object

# %% [markdown]
# Rename columns
#
# Year of event	int64
# Event dates	object
# Event name	object
# Event distance/length	object
# Event number of finishers	int64
# Athlete performance	object
# Athlete gender	object
# Athlete average speed	float64
# Athlete ID	float64
# athlete age	int66

# %%
df2 = df2.rename(columns={'Year of event': 'year', 'Event dates': 'race_day', 'Event name': 'race_name', 'Event distance/length': 'race_length', 'Event number of finishers': 'race_number_of_finishers', 'Athlete performance': 'athlete_performance', 'Athlete gender': 'athlete_gender', 'Athlete average speed': 'athlete_average_speed', 'Athlete ID': 'athlete_id'})

# %%
df2.head()
# Out:
#    year    race_day       race_name race_length  race_number_of_finishers  \
# 0  2018  06.01.2018  Selva Costera         50km                        22
# 1  2018  06.01.2018  Selva Costera         50km                        22
# 2  2018  06.01.2018  Selva Costera         50km                        22
# 3  2018  06.01.2018  Selva Costera         50km                        22
# 4  2018  06.01.2018  Selva Costera         50km                        22
#
#   athlete_performance athlete_gender  athlete_average_speed  athlete_id  \
# 0             4:51:39              M                 10.286         0.0
# 1             5:15:45              M                  9.501         1.0
# 2             5:16:44              M                  9.472         2.0
# 3             5:34:13              M                  8.976         3.0
# 4             5:54:14              M                  8.469         4.0
#
#    athlete age
# 0           40
# 1           37
# 2           31
# 3           42
# ...

# %% [markdown]
# Recorder columns

# %%
df3 = df2[['year', 'race_day', 'race_name', 'race_length', 'race_number_of_finishers', 'athlete_performance', 'athlete_gender', 'athlete_average_speed', 'athlete_id', 'athlete age']]

# %%
df3.head()
# Out:
#    year    race_day       race_name race_length  race_number_of_finishers  \
# 0  2018  06.01.2018  Selva Costera         50km                        22
# 1  2018  06.01.2018  Selva Costera         50km                        22
# 2  2018  06.01.2018  Selva Costera         50km                        22
# 3  2018  06.01.2018  Selva Costera         50km                        22
# 4  2018  06.01.2018  Selva Costera         50km                        22
#
#   athlete_performance athlete_gender  athlete_average_speed  athlete_id  \
# 0             4:51:39              M                 10.286         0.0
# 1             5:15:45              M                  9.501         1.0
# 2             5:16:44              M                  9.472         2.0
# 3             5:34:13              M                  8.976         3.0
# 4             5:54:14              M                  8.469         4.0
#
#    athlete age
# 0           40
# 1           37
# 2           31
# 3           42
# ...

# %% [markdown]
# Find 2 races that I ran in 2018

# %%
df3[df3['race_name'] == 'Selva Costera ']
# Out:
#     year    race_day       race_name race_length  race_number_of_finishers  \
# 0   2018  06.01.2018  Selva Costera         50km                        22
# 1   2018  06.01.2018  Selva Costera         50km                        22
# 2   2018  06.01.2018  Selva Costera         50km                        22
# 3   2018  06.01.2018  Selva Costera         50km                        22
# 4   2018  06.01.2018  Selva Costera         50km                        22
# 5   2018  06.01.2018  Selva Costera         50km                        22
# 6   2018  06.01.2018  Selva Costera         50km                        22
# 7   2018  06.01.2018  Selva Costera         50km                        22
# 8   2018  06.01.2018  Selva Costera         50km                        22
# 9   2018  06.01.2018  Selva Costera         50km                        22
# 10  2018  06.01.2018  Selva Costera         50km                        22
# ...

# %% [markdown]
# Find 21.0

# %%
df3[df3['athlete_id'] == 222509]
# Out:
# Empty DataFrame
# Columns: [year, race_day, race_name, race_length, race_number_of_finishers, athlete_performance, athlete_gender, athlete_average_speed, athlete_id, athlete age]
# Index: []

# %% [markdown]
# Charts and graphs

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.distplot(df3[df3['race_length'] == '50km']['athlete_average_speed'])
# Out:
# <ipython-input-57-186bfc1a05be>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3[df3['race_length'] == '50km']['athlete_average_speed'])
# <Axes: xlabel='athlete_average_speed', ylabel='Density'>

# %%
sns.violinplot(data = df3, x='race_length', y='athlete_average_speed', hue='athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %% [markdown]
# difference in speed for the 50km male to female

# %%
df3.groupby(['athlete_gender', 'race_length'])['athlete_average_speed'].mean()
# Out:
# athlete_gender  race_length
# F               50km           6.923200
# M               50km           7.789929
# Name: athlete_average_speed, dtype: float64
